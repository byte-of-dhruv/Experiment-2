# %% [markdown]
# Dhruv Verulkar
#
# 25070123162
#
# Exp 2: Study Of List in Python

# %%
list1= ["apple", "banana", "orange"]
print (list1)
# Out:
# ['apple', 'banana', 'orange']

# %%
list2 = [2,2.3, "dhruv", True]
print (list2)
# Out:
# [2, 2.3, 'dhruv', True]

# %%
list3= ["apple", "orange", "apple", "cherry"]
print(list3)
# Out:
# ['apple', 'orange', 'apple', 'cherry']

# %%
list4= ["apple", "banana", "orange", "cherry", "mango", "kiwi"]
print(list4[2])
print(list4[-4])
print(list4[2:5])
print(list4[:4])
print(list4[2:])
# Out:
# orange
# orange
# ['orange', 'cherry', 'mango']
# ['apple', 'banana', 'orange', 'cherry']
# ['orange', 'cherry', 'mango', 'kiwi']

# %%
list5= ["apple", "orange", "mango"]
list5[1]= "cherry"
print(list5)
# Out:
# ['apple', 'cherry', 'mango']

# %%
list6= ["apple", "orange", "cherry"]
list6.append("mango")
print(list6)
# Out:
# ['apple', 'orange', 'cherry', 'mango']

# %%
list7= ["apple", "banana", "orange"]
list7.insert(1, "mango")
print(list7)
# Out:
# ['apple', 'mango', 'banana', 'orange']

# %%
list8=["apple", "banana", "orange"]
list9=["kiwi", "mango"]
list8.extend(list9)
print(list8+list9)
print(list8)
# Out:
# ['apple', 'banana', 'orange', 'kiwi', 'mango', 'kiwi', 'mango']
# ['apple', 'banana', 'orange', 'kiwi', 'mango']

# %%
marks= [90, 82, 66, 76, 33]
print(max(marks))
print(min(marks))
print(len(marks))
print(sum(marks))
print(sorted(marks))
print(sum(marks)/len(marks))
marks.sort()
print(marks)
# Out:
# 90
# 33
# 5
# 347
# [33, 66, 76, 82, 90]
# 69.4
# [33, 66, 76, 82, 90]

# %%
grocery = ["Milk", "Oats", "Eggs", "Orange Juice", "Paneer"]
grocery.append("Chili")
grocery.append("Coffee")
grocery.append("Salt")
grocery.remove("Eggs")
grocery.remove("Milk")
print(grocery)
# Out:
# ['Oats', 'Orange Juice', 'Paneer', 'Chili', 'Coffee', 'Salt']
